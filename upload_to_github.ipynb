# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/drive/MyDrive/sentiment-analysis-for-movie-reviews/* /content/sentiment-analysis-for-movie-reviews/

# %%
# %cd sentiment-analysis-for-movie-reviews
# Out:
# /content/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews

# %%
# %cd /content/sentiment-analysis-for-movie-reviews

# Bước 1: Add toàn bộ thay đổi
# !git add .

# Bước 2: Commit với message rõ ràng
# !git commit -m "Thêm file Don_Xin_Nghi_Phep.docx vào thư mục DeepLearning"

# Bước 3: Push lên GitHub
# !git push origin main
# Out:
# /content/sentiment-analysis-for-movie-reviews
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> sentiment-analysis-for-movie-reviews
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached sentiment-analysis-for-movie-reviews
# hint:
# hint: See "git help submodule" for more information.
# [main 293c107] Thêm file Don_Xin_Nghi_Phep.docx vào thư mục DeepLearning
#  3 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 DeepLearning/Don_Xin_Nghi_Phep.docx
#  create mode 160000 sentiment-analysis-for-movie-reviews
#  rewrite upload_to_github.ipynb (97%)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# ...

# %%
# !git rm --cached -r sentiment-analysis-for-movie-reviews
# Out:
# rm 'sentiment-analysis-for-movie-reviews'

# %%
# !git commit -m "Remove nested git repository"
# !git push origin main
# Out:
# [main 18fff3e] Remove nested git repository
#  1 file changed, 1 deletion(-)
#  delete mode 160000 sentiment-analysis-for-movie-reviews
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 249 bytes | 249.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:NguyenHoangXuanSon/sentiment-analysis-for-movie-reviews.git
#    293c107..18fff3e  main -> main

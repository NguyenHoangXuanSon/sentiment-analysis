# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/NguyenHoangXuanSon/sentiment-analysis-for-movie-reviews.git
# Out:
# Cloning into 'sentiment-analysis-for-movie-reviews'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 15 (delta 4), reused 15 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 4.86 MiB | 6.44 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !cp -r /content/drive/MyDrive/sentiment-analysis-for-movie-reviews/* /content/sentiment-analysis-for-movie-reviews/

# %%
# %cd sentiment-analysis-for-movie-reviews
# Out:
# /content/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews/sentiment-analysis-for-movie-reviews

# %%
# !git add .
# Out:
# origin	https://github.com/NguyenHoangXuanSon/sentiment-analysis-for-movie-reviews.git (fetch)
# origin	https://github.com/NguyenHoangXuanSon/sentiment-analysis-for-movie-reviews.git (push)

# %%
# !git remote set-url origin git@github.com:NguyenHoangXuanSon/sentiment-analysis-for-movie-reviews.git

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !ls /content/sentiment-analysis-for-movie-reviews/DeepLearning/
# Out:
# Don_Xin_Nghi_Phep.docx

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NguyenHoangXuanSon/sentiment-analysis-for-movie-reviews.git
# Out:
# Cloning into 'sentiment-analysis-for-movie-reviews'...
# warning: You appear to have cloned an empty repository.

# %%
# !cp -r /content/drive/MyDrive/sentiment-analysis-for-movie-reviews/* /content/sentiment-analysis-for-movie-reviews/

# %%
# !cp -r /content/drive/MyDrive/sentiment-analysis-for-movie-reviews/* /content/sentiment-analysis-for-movie-reviews/

# %%
# %cd /content/sentiment-analysis-for-movie-reviews

# !git config --global user.email "xuanson522004@gmail.com"
# !git config --global user.name "Nguyen Hoang Xuan Son"

# !git add .
# !git commit -m "Push full project from Drive"
# !git push origin main
# Out:
# /content/sentiment-analysis-for-movie-reviews
# [main (root-commit) a7af9f7] Push full project from Drive
#  8 files changed, 270274 insertions(+)
#  create mode 100644 DataPreprocessing/DataPreprocessing.ipynb
#  create mode 100644 DataPreprocessing/SST2 text augmentation.ipynb
#  create mode 100644 DataPreprocessing/TestSet_orig_eda_embedding_wordnet.csv
#  create mode 100644 DataPreprocessing/TrainingSet_orig_eda_embedding_wordnet.csv
#  create mode 100644 MachineLearning/KNN.ipynb
#  create mode 100644 MachineLearning/Logistic_Regression.ipynb
#  create mode 100644 MachineLearning/SVM.ipynb
#  create mode 100644 upload_to_github.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address
